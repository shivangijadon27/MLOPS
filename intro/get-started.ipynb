# %% [markdown]
# # MLFLOW Tracking Server

# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://localhost:5000")

# %%
mlflow.set_experiment("check local mlflow server")

with mlflow.start_run():
    mlflow.log_metric("test",1)
